# %% [markdown]
# #

# %%
class Car():
    def __init__(self, x = 3):
        self.num_wheels = x
    def drive(self):
        print(f"Driving on {self.num_wheels} wheels")

# %%
C = Car()
C.drive()
# Out:
# Driving on 3 wheels
