# %% [markdown]
# #

# %%
import numpy as np

# %%
2 + 2
# Out:
# 4

# %%
s = "hello, world"

# %%
x = 2
type(x)
# Out:
# int

# %%
type(s)
# Out:
# str

# %%
y = 2.2
type(y)
# Out:
# float

# %%
b = True
type(b)
# Out:
# bool

# %%
type(None)
# Out:
# NoneType

# %%
c = 'c'
type(c)
# Out:
# str

# %%
s = 2
type(s)
# Out:
# int
