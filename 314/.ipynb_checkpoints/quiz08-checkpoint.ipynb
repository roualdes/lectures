# %%
import numpy as np
import scipy.stats as st

# %%
Poisson = st.poisson

# %%
l = 1.5 / 100 * 48

# %%
X = Poisson(l)
X.pmf(0)
# Out:
# 0.4867522559599717

# %%
np.sum(X.pmf(np.arange(6)))
# Out:
# 0.9998951831177709

# %%
Y = Poisson(1.5 / 100 * 24)
1 - np.sum(Y.pmf(np.arange(3)))
# Out:
# 0.00595077061399496
