# %% [markdown]
# #

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st

# %%
R = 1000
N = 101
rng = np.random.default_rng()
cms = np.zeros(R)
for r in range(R):          
    x = rng.binomial(10, 0.5, size = N)
    cms[r] = np.mean(x)

# %%
Binomial = st.binom
B = Binomial(10, 0.5)
(B.mean(), B.var())
# Out:
# (5.0, 2.5)

# %%
Normal = st.norm
Nd = Normal(loc = B.mean(), scale = np.sqrt(B.var() / N))

# %%
xx = np.linspace(3, 7, 201)
fx = Nd.pdf(xx)
plt.plot(xx, fx)
plt.hist(cms, density = True, histtype = "step");

# %%
plt.hist(x, density = True, histtype = "step");

# %%
x = rng.binomial(10, 0.5, size = N)

# %%
np.mean(x) - Normal().ppf(0.975) * np.sqrt(np.var(x) / N)
# Out:
# 4.614056484048096

# %%
np.mean(x) + Normal().ppf(0.975) * np.sqrt(np.var(x) / N)
# Out:
# 5.1681217337736856
