# %% [markdown]
# #

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 10000
rng = np.random.default_rng()
x = rng.normal(size = N)
xbar = np.mean(x)
np.var(x)
# Out:
# 0.9926945605171044

# %%
ndx = np.arange(N) + 1
cm = np.cumsum(x) / ndx
plt.plot(ndx, cm)

# %%
cv = np.cumsum((x - xbar) ** 2) / ndx
plt.plot(ndx, cv)
